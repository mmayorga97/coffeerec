# %% [markdown]
# # Recommender

# %% [markdown]
# # Data Load Test

# %%
import pandas as pd
data = pd.read_csv('app/coffee_may2023_prep.csv')
data.head(10)
# Out:
#                                 lot_number                      producer  \
# 0                               cqu2022015         diego samuel bermudez
# 1  the 2022 pacific rim coffee summit,t037                           曾福森
# 2  the 2022 pacific rim coffee summit,la01                    wu tao chi
# 3                               cqu2022017           santa maria de dota
# 4                               cqu2023002              camilo merizalde
# 5  the 2022 pacific rim coffee summit,gt02  emilio antonio medina garcia
# 6  the 2022 pacific rim coffee summit,t034                           黃保錫
# 7  the 2022 pacific rim coffee summit,t050                           莊家榮
# 8  the 2022 pacific rim coffee summit,t018                           鍾旭亮
# 9                 cn 4127230034/4189230113            dorman (t) limited
#
#                             mill             country_of_origin      variety  \
# 0               finca el paraiso                      colombia     castillo
# 1       royal bean geisha estate                        taiwan        gesha
# 2  oklao coffee processing plant                          laos         java
# 3        la montana tarrazu mill                    costa rica        gesha
# 4                finca santuario                      colombia  red bourbon
# 5                  dinámica café                     guatemala        gesha
# 6                          野牡丹咖啡                        taiwan        gesha
# 7                       七彩琉璃咖啡莊園                        taiwan   sl34+gesha
# 8                         亮軒咖啡莊園                        taiwan         sl34
# 9            gourmet coffee mill  tanzania, united republic of      bourbon
#
#          processing_method  aroma  flavor  aftertaste  acidity  body  balance  \
# 0  double anaerobic washed   8.58    8.50        8.42     8.58  8.25     8.42
# 1             washed / wet   8.50    8.50        7.92     8.00  7.92     8.25
# 2              semi washed   8.33    8.42        8.08     8.17  7.92     8.17
# 3             washed / wet   8.08    8.17        8.17     8.25  8.17     8.08
# 4             honey,mossto   8.33    8.33        8.08     8.25  7.92     7.92
# 5             washed / wet   8.33    8.33        8.25     7.83  7.83     8.17
# 6             washed / wet   8.33    8.17        8.08     8.00  7.83     8.25
# 7            natural / dry   8.25    8.25        8.17     8.00  7.92     8.08
# 8             washed / wet   8.08    8.08        8.25     8.08  7.92     8.00
# 9             washed / wet   8.08    8.17        8.08     8.17  8.00     8.00
#
#    moisture_percentage  quakers         color  altitude
# 0                 11.8        0         green    1815.0
# 1                 10.5        0    blue-green    1200.0
# 2                 10.4        0     yellowish    1300.0
# 3                 11.8        0         green    1900.0
# 4                 11.6        2  yellow-green    1975.0
# 5                 10.7        0         green    1668.0
# 6                  9.1        0         green    1250.0
# 7                 10.0        0  yellow-green    1200.0
# 8                 10.8        0      greenish    1250.0
# 9                 11.0        0      greenish    1550.0

# %% [markdown]
# # Recommender
#
# - This recommender is based in [Cosine Similarity](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.cosine_similarity.html#sklearn.metrics.pairwise.cosine_similarity): used in information retrieval and item vectorized attributes. It calculates the similarity between two vectors.
# - The vectors are created from coffee's string features and the normalized values [0 , 1] of its numeric features.
# - string features: 'variety', 'processing_method','color', 'country_of_origin', 'mill'
# - numeric features: 'aftertaste','balance','flavor','aroma','body','acidity','moisture_percentage','quakers','overall','total_cup_points','altitude'
# - a search used by key (column name) and its value, helps to retrieve a base coffee ID to get the recommendation.

# %%
# Imports
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import linear_kernel
import random

# Load preprocessed data
data = pd.read_csv('app/coffee_may2023_prep.csv')

def get_coffee_recommendation(key_value='costa rica',key_id='country_of_origin', top_n=10):
        # Concatenate multiple columns into a single feature column for item representation
        coffee_item_features = ['variety', 'processing_method','color', 'country_of_origin', 'mill']
        data['item_features'] = data[coffee_item_features].agg(' '.join, axis=1)

        # Normalize 'rating' column to [0, 1] range for feature representation
        scaler = MinMaxScaler()
        normalized_columns = ['aftertaste','balance','flavor','aroma','body','acidity','moisture_percentage','quakers','altitude']
        normalized_features = scaler.fit_transform(data[normalized_columns])
        normalized_data = pd.DataFrame(normalized_features, columns=normalized_columns)

        # Create a TF-IDF vectorizer to convert item_features into feature vectors
        tfidf_vectorizer = TfidfVectorizer(stop_words='english')
        tfidf_matrix = tfidf_vectorizer.fit_transform(data['item_features'])

        # Combine the TF-IDF matrix with the normalized columns
        data_vec = pd.concat([pd.DataFrame(tfidf_matrix.toarray()), normalized_data], axis=1)

        # Calculate the cosine similarity between items
        cosine_sim = linear_kernel(data_vec, data_vec)

        # Function to get coffee recommendations based on country
        def get_recommendations(key_value,key_id, cosine_similarities, data):
            idx = random.choice(data.index[data[key_id] == key_value].tolist())
            sim_scores = list(enumerate(cosine_similarities[idx]))
            sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
            sim_scores = sim_scores[1:]  # Exclude the base coffee itself (most similar)
            coffee_indices = [i[0] for i in sim_scores]
            return data[['producer']+coffee_item_features+normalized_columns].iloc[coffee_indices]
        # get recommendations using a key and value
        recommendations = get_recommendations(key_value,key_id, cosine_sim, data)
        
        # add search
        def generate_url(row):
            return f'<a target="_blank" href="https://search.brave.com/search?q={row["producer"]} + {row["mill"]}">Info</a>'

        recommendations.insert(0, 'Search', recommendations.apply(generate_url,axis=1))
        # return top_n values
        return recommendations[0:top_n]

# %% [markdown]
# # Test

# %% [markdown]
# ## by Country

# %%
get_coffee_recommendation(key_value='costa rica',key_id='country_of_origin', top_n=10)
# Out:
#                                                Search  \
# 0   <a target="_blank" href="https://search.brave....
# 14  <a target="_blank" href="https://search.brave....
# 68  <a target="_blank" href="https://search.brave....
# 4   <a target="_blank" href="https://search.brave....
# 1   <a target="_blank" href="https://search.brave....
# 2   <a target="_blank" href="https://search.brave....
# 5   <a target="_blank" href="https://search.brave....
# 12  <a target="_blank" href="https://search.brave....
# 47  <a target="_blank" href="https://search.brave....
# 13  <a target="_blank" href="https://search.brave....
#
#                         producer      variety        processing_method  \
# 0          diego samuel bermudez     castillo  double anaerobic washed
# 14           josue enciso suarez      caturra             washed / wet
# 68           santa maria de dota        gesha             washed / wet
# 4               camilo merizalde  red bourbon             honey,mossto
# 1                            曾福森        gesha             washed / wet
# 2                     wu tao chi         java              semi washed
# 5   emilio antonio medina garcia        gesha             washed / wet
# 12                           賴彥合        gesha             washed / wet
# 47                    pablo chuy       catuai             washed / wet
# 13                    kerchanshe        gesha            natural / dry
#
#            color country_of_origin                           mill  aftertaste  \
# 0          green          colombia               finca el paraiso        8.42
# 14         green          colombia                    la gaitania        8.08
# 68         green        costa rica        la montana tarrazu mill        7.67
# 4   yellow-green          colombia                finca santuario        8.08
# 1     blue-green            taiwan       royal bean geisha estate        7.92
# 2      yellowish              laos  oklao coffee processing plant        8.08
# 5          green         guatemala                  dinámica café        8.25
# 12         green            taiwan                         古峰咖啡莊園        8.08
# 47         green         guatemala         beneficio las americas        7.75
# 13  yellow-green          ethiopia   dry mill or hulling facility        8.00
#
#     balance  flavor  aroma  body  acidity  moisture_percentage  quakers  \
# 0      8.42    8.50   8.58  8.25     8.58                 11.8        0
# 14     8.00    8.00   8.08  8.08     7.92                 10.6        0
# 68     7.75    7.83   7.75  7.75     7.83                 11.7        1
# 4      7.92    8.33   8.33  7.92     8.25                 11.6        2
# 1      8.25    8.50   8.50  7.92     8.00                 10.5        0
# 2      8.17    8.42   8.33  7.92     8.17                 10.4        0
# 5      8.17    8.33   8.33  7.83     7.83                 10.7        0
# 12     8.00    8.00   8.08  8.00     8.08                 11.9        0
# 47     7.83    8.00   7.67  8.00     7.92                 11.3        0
# 13     8.00    8.17   7.67  8.00     8.33                 11.6        3
#
#     altitude
# 0     1815.0
# 14    1850.0
# 68    1900.0
# 4     1975.0
# 1     1200.0
# 2     1300.0
# 5     1668.0
# 12    1250.0
# 47    4700.0
# 13    1950.0

# %% [markdown]
# ## by Color

# %%
get_coffee_recommendation(key_value='greenish',key_id='color', top_n=10)
# Out:
#                                                 Search  \
# 19   <a target="_blank" href="https://search.brave....
# 0    <a target="_blank" href="https://search.brave....
# 91   <a target="_blank" href="https://search.brave....
# 53   <a target="_blank" href="https://search.brave....
# 3    <a target="_blank" href="https://search.brave....
# 4    <a target="_blank" href="https://search.brave....
# 2    <a target="_blank" href="https://search.brave....
# 128  <a target="_blank" href="https://search.brave....
# 1    <a target="_blank" href="https://search.brave....
# 5    <a target="_blank" href="https://search.brave....
#
#                          producer      variety        processing_method  \
# 19             dorman (t) limited      bourbon             washed / wet
# 0           diego samuel bermudez     castillo  double anaerobic washed
# 91                         dorman      bourbon             washed / wet
# 53                   iyenga amcos      bourbon             washed / wet
# 3             santa maria de dota        gesha             washed / wet
# 4                camilo merizalde  red bourbon             honey,mossto
# 2                      wu tao chi         java              semi washed
# 128           dorman tanzania ltd      bourbon             washed / wet
# 1                             曾福森        gesha             washed / wet
# 5    emilio antonio medina garcia        gesha             washed / wet
#
#             color             country_of_origin  \
# 19       greenish  tanzania, united republic of
# 0           green                      colombia
# 91       greenish  tanzania, united republic of
# 53       greenish  tanzania, united republic of
# 3           green                    costa rica
# 4    yellow-green                      colombia
# 2       yellowish                          laos
# 128      greenish  tanzania, united republic of
# 1      blue-green                        taiwan
# 5           green                     guatemala
#
#                               mill  aftertaste  balance  flavor  aroma  body  \
# 19             gourmet coffee mill        7.92     7.75    8.00   8.17  8.17
# 0                 finca el paraiso        8.42     8.42    8.50   8.58  8.25
# 91             gourmet coffee mill        7.58     7.75    7.58   7.75  7.67
# 53                 city coffee ltd        7.75     7.83    7.75   7.92  7.83
# 3          la montana tarrazu mill        8.17     8.08    8.17   8.08  8.17
# 4                  finca santuario        8.08     7.92    8.33   8.33  7.92
# 2    oklao coffee processing plant        8.08     8.17    8.42   8.33  7.92
# 128            gourmet coffee mill        7.42     7.58    7.67   7.92  7.67
# 1         royal bean geisha estate        7.92     8.25    8.50   8.50  7.92
# 5                    dinámica café        8.25     8.17    8.33   8.33  7.83
#
#      acidity  moisture_percentage  quakers  altitude
# 19      7.92                 10.0        0    1585.0
# 0       8.58                 11.8        0    1815.0
# 91      7.92                 11.6        0    1550.0
# 53      7.92                 11.2        0    1654.0
# 3       8.25                 11.8        0    1900.0
# 4       8.25                 11.6        2    1975.0
# 2       8.17                 10.4        0    1300.0
# 128     7.50                 10.4        0    1550.0
# 1       8.00                 10.5        0    1200.0
# 5       7.83                 10.7        0    1668.0

# %% [markdown]
# ## by Processing Method

# %%
get_coffee_recommendation(key_value='natural / dry',key_id='processing_method', top_n=10)
# Out:
#                                                 Search  \
# 4    <a target="_blank" href="https://search.brave....
# 107  <a target="_blank" href="https://search.brave....
# 3    <a target="_blank" href="https://search.brave....
# 7    <a target="_blank" href="https://search.brave....
# 13   <a target="_blank" href="https://search.brave....
# 1    <a target="_blank" href="https://search.brave....
# 2    <a target="_blank" href="https://search.brave....
# 11   <a target="_blank" href="https://search.brave....
# 5    <a target="_blank" href="https://search.brave....
# 9    <a target="_blank" href="https://search.brave....
#
#                          producer                         variety  \
# 4                camilo merizalde                     red bourbon
# 107                           lim  catimor,catuai,caturra,bourbon
# 3             santa maria de dota                           gesha
# 7                             莊家榮                      sl34+gesha
# 13                     kerchanshe                           gesha
# 1                             曾福森                           gesha
# 2                      wu tao chi                            java
# 11                 karen acajabon                           gesha
# 5    emilio antonio medina garcia                           gesha
# 9              dorman (t) limited                         bourbon
#
#     processing_method         color             country_of_origin  \
# 4        honey,mossto  yellow-green                      colombia
# 107     natural / dry   pale-yellow                       myanmar
# 3        washed / wet         green                    costa rica
# 7       natural / dry  yellow-green                        taiwan
# 13      natural / dry  yellow-green                      ethiopia
# 1        washed / wet    blue-green                        taiwan
# 2         semi washed     yellowish                          laos
# 11      natural / dry      brownish                     guatemala
# 5        washed / wet         green                     guatemala
# 9        washed / wet      greenish  tanzania, united republic of
#
#                               mill  aftertaste  balance  flavor  aroma  body  \
# 4                  finca santuario        8.08     7.92    8.33   8.33  7.92
# 107                       aromatic        7.67     7.58    7.83   7.83  7.58
# 3          la montana tarrazu mill        8.17     8.08    8.17   8.08  8.17
# 7                         七彩琉璃咖啡莊園        8.17     8.08    8.25   8.25  7.92
# 13    dry mill or hulling facility        8.00     8.00    8.17   7.67  8.00
# 1         royal bean geisha estate        7.92     8.25    8.50   8.50  7.92
# 2    oklao coffee processing plant        8.08     8.17    8.42   8.33  7.92
# 11                      cafetoland        8.00     8.17    8.00   8.08  8.25
# 5                    dinámica café        8.25     8.17    8.33   8.33  7.83
# 9              gourmet coffee mill        8.08     8.00    8.17   8.08  8.00
#
#      acidity  moisture_percentage  quakers  altitude
# 4       8.25                 11.6        2    1975.0
# 107     7.58                 10.2        1    1400.0
# 3       8.25                 11.8        0    1900.0
# 7       8.00                 10.0        0    1200.0
# 13      8.33                 11.6        3    1950.0
# 1       8.00                 10.5        0    1200.0
# 2       8.17                 10.4        0    1300.0
# 11      7.75                 11.5        0    2000.0
# 5       7.83                 10.7        0    1668.0
# 9       8.17                 11.0        0    1550.0
